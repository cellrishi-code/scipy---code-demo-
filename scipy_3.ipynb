# %% [markdown]
# <a href="https://colab.research.google.com/github/cellrishi-code/scipy---code-demo-/blob/main/scipy_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## basic synatx
# from scipy import integrate as int

# result, error = int.quad(function, a, b)

# %%
from scipy import integrate
import numpy as np

f = lambda x: x**2

result, error = integrate.quad(f, 0, 3)

print("Result:", result)
print("Error:", error)
# Out:
# Result: 9.000000000000002
# Error: 9.992007221626411e-14
